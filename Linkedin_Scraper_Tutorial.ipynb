# %%
#Import dependencies
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd

# %%
title = "Python Developer"  # Job title
location = "Toronto"  # Job location
start = 0  # Starting point for pagination

# %%
# Construct the URL for LinkedIn job search
list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={title}&location={location}&start={start}"

# Send a GET request to the URL and store the response
response = requests.get(list_url)

#Get the HTML, parse the response and find all list items(jobs postings)
list_data = response.text
list_soup = BeautifulSoup(list_data, "html.parser")
page_jobs = list_soup.find_all("li")

# %%
#Create an empty list to store the job postings
id_list = []

# %%
#Itetrate through job postings to find job ids
for job in page_jobs:
    base_card_div = job.find("div", {"class": "base-card"})
    job_id = base_card_div.get("data-entity-urn").split(":")[3]
    print(job_id)
    id_list.append(job_id)
# Out:
# 3784870641
# 3829971798
# 3843336654
# 3757581041
# 3844987400
# 3821063570
# 3818819127
# 3741139431
# 3844992099
# 3844989232

# %%
# Initialize an empty list to store job information
job_list = []

# Loop through the list of job IDs and get each URL
for job_id in id_list:
    # Construct the URL for each job using the job ID
    job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
    
    # Send a GET request to the job URL and parse the reponse
    job_response = requests.get(job_url)
    print(job_response.status_code)
    job_soup = BeautifulSoup(job_response.text, "html.parser")
    
     # Create a dictionary to store job details
    job_post = {}
    
    # Try to extract and store the job title
    try:
        job_post["job_title"] = job_soup.find("h2", {"class":"top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
    except:
        job_post["job_title"] = None
        
    # Try to extract and store the company name
    try:
        job_post["company_name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
    except:
        job_post["company_name"] = None
        
    # Try to extract and store the time posted
    try:
        job_post["time_posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
    except:
        job_post["time_posted"] = None
        
    # Try to extract and store the number of applicants
    try:
        job_post["num_applicants"] = job_soup.find("span", {"class": "num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet"}).text.strip()
    except:
        job_post["num_applicants"] = None
    
        
    # Append the job details to the job_list
    job_list.append(job_post)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
#Check if the list contains all the desired data
job_list
# Out:
# [{'job_title': 'Full Stack Web Developer (Python)',
#   'company_name': 'PIXOMONDO',
#   'time_posted': '6 days ago',
#   'num_applicants': '94 applicants'},
#  {'job_title': 'Python Developer',
#   'company_name': 'Luxoft',
#   'time_posted': '1 day ago',
#   'num_applicants': None},
#  {'job_title': 'Senior Python Developer',
#   'company_name': 'Prodigy Labs a UST Company',
#   'time_posted': '4 days ago',
#   'num_applicants': None},
#  {'job_title': 'Web Developer',
#   'company_name': 'TV2 Consulting',
#   'time_posted': '4 months ago',
#   'num_applicants': None},
#  {'job_title': 'Développeur Python/Développeuse Python',
#   'company_name': 'Astek Canada',
#   'time_posted': '1 day ago',
#   'num_applicants': '102 applicants'},
#  {'job_title': 'Python Developer CTS',
#   'company_name': 'Diverse Lynx',
#   'time_posted': '1 week ago',
#   'num_applicants': '33 applicants'},
#  {'job_title': 'Backend Developers- Canada',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '2 months ago',
#   'num_applicants': '85 applicants'},
#  {'job_title': 'Full-stack developer',
#   'company_name': 'Experfy',
#   'time_posted': '11 months ago',
#   'num_applicants': None},
#  {'job_title': 'Junior Web Developer',
#   'company_name': 'Clio - Cloud-Based Legal Technology',
#   'time_posted': '2 weeks ago',
#   'num_applicants': None},
#  {'job_title': 'Web Applications Developer',
#   'company_name': 'TV2 Consulting',
#   'time_posted': '1 month ago',
#   'num_applicants': None},
#  {'job_title': 'Full Stack Developers',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '2 months ago',
#   'num_applicants': '107 applicants'},
#  {'job_title': 'Full Stack Engineer',
#   'company_name': 'Nightfall AI',
#   'time_posted': '3 weeks ago',
#   'num_applicants': None},
#  {'job_title': 'Python Library Developer',
#   'company_name': 'Veritas Search Group',
#   'time_posted': '1 week ago',
#   'num_applicants': '41 applicants'},
#  {'job_title': 'Senior Full-stack Developer',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '4 months ago',
#   'num_applicants': '146 applicants'},
#  {'job_title': 'SDET (Selenium/ Java/Python)',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '1 week ago',
#   'num_applicants': '35 applicants'},
#  {'job_title': 'Senior Software Engineer | Python Developer',
#   'company_name': 'Scotiabank',
#   'time_posted': '1 week ago',
#   'num_applicants': None},
#  {'job_title': 'Python Developer- ONSITE',
#   'company_name': 'Diverse Lynx',
#   'time_posted': '1 month ago',
#   'num_applicants': None},
#  {'job_title': 'Full Stack developer -Designer',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '4 months ago',
#   'num_applicants': '168 applicants'},
#  {'job_title': 'UI Web Developer',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '1 week ago',
#   'num_applicants': '87 applicants'},
#  {'job_title': 'Full stack Developer',
#   'company_name': 'Zortech Solutions',
#   'time_posted': '1 week ago',
#   'num_applicants': '44 applicants'}]

# %%
# Create a pandas DataFrame using the list of job dictionaries 'job_list'
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#                                       job_title
# 0             Full Stack Web Developer (Python)  \
# 1                              Python Developer
# 2                       Senior Python Developer
# 3                                 Web Developer
# 4        Développeur Python/Développeuse Python
# 5                          Python Developer CTS
# 6                    Backend Developers- Canada
# 7                          Full-stack developer
# 8                          Junior Web Developer
# 9                    Web Applications Developer
# 10                        Full Stack Developers
# 11                          Full Stack Engineer
# 12                     Python Library Developer
# 13                  Senior Full-stack Developer
# 14                 SDET (Selenium/ Java/Python)
# 15  Senior Software Engineer | Python Developer
# 16                     Python Developer- ONSITE
# 17               Full Stack developer -Designer
# 18                             UI Web Developer
# 19                         Full stack Developer
#
#                            company_name    time_posted  num_applicants
# 0                             PIXOMONDO     6 days ago   94 applicants
# 1                                Luxoft      1 day ago            None
# 2            Prodigy Labs a UST Company     4 days ago            None
# 3                        TV2 Consulting   4 months ago            None
# 4                          Astek Canada      1 day ago  102 applicants
# 5                          Diverse Lynx     1 week ago   33 applicants
# 6                     Zortech Solutions   2 months ago   85 applicants
# 7                               Experfy  11 months ago            None
# 8   Clio - Cloud-Based Legal Technology    2 weeks ago            None
# 9                        TV2 Consulting    1 month ago            None
# 10                    Zortech Solutions   2 months ago  107 applicants
# 11                         Nightfall AI    3 weeks ago            None
# 12                 Veritas Search Group     1 week ago   41 applicants
# 13                    Zortech Solutions   4 months ago  146 applicants
# 14                    Zortech Solutions     1 week ago   35 applicants
# 15                           Scotiabank     1 week ago            None
# 16                         Diverse Lynx    1 month ago            None
# 17                    Zortech Solutions   4 months ago  168 applicants
# 18                    Zortech Solutions     1 week ago   87 applicants
# 19                    Zortech Solutions     1 week ago   44 applicants

# %%
#Save data to CSV file
jobs_df.to_csv('Toronto_Python_Developer.csv', index = False)
